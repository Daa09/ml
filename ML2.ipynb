# %%
import pandas as pd

# %%
 df = pd.read_csv('/content/covid.csv')

# %%
df.head()
# Out:
#    Actual  Predicted
# 0       1          1
# 1       1          1
# 2       1          1
# 3       1          1
# 4       1          1

# %%
X = df['Actual']
Y = df['Predicted']

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(X,Y)
print("Accuracy Score is: ",accuracy)
from sklearn.metrics import precision_score
precision_1 = precision_score(X,Y)
print("Precision is: ",precision_1)
from sklearn.metrics import recall_score
recall_1 = recall_score(X,Y)
print("Recall Score: ",recall_1)
from sklearn.metrics import f1_score
f1_1 = f1_score(X,Y)
print("F1 Score is: ",f1_1)
# Out:
# Accuracy Score is:  0.88
# Precision is:  0.45
# Recall Score:  0.9
# F1 Score is:  0.6

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(confusion_matrix(X,Y), annot=True ,cmap='bues')
